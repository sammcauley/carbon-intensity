# %%
import requests
from IPython.display import JSON
import pprint

# %%
headers = {
  'Accept': 'application/json'
}
 
r = requests.get('https://api.carbonintensity.org.uk/intensity/2026-04-02T15:00Z/2026-04-09T15:00Z', params={}, headers = headers)
 
pprint.pprint(r.json()["data"])
# Out:
# [{'from': '2026-04-02T14:30Z',
#   'intensity': {'actual': 81, 'forecast': 81, 'index': 'low'},
#   'to': '2026-04-02T15:00Z'},
#  {'from': '2026-04-02T15:00Z',
#   'intensity': {'actual': 90, 'forecast': 92, 'index': 'moderate'},
#   'to': '2026-04-02T15:30Z'},
#  {'from': '2026-04-02T15:30Z',
#   'intensity': {'actual': 111, 'forecast': 106, 'index': 'moderate'},
#   'to': '2026-04-02T16:00Z'},
#  {'from': '2026-04-02T16:00Z',
#   'intensity': {'actual': 126, 'forecast': 113, 'index': 'moderate'},
#   'to': '2026-04-02T16:30Z'},
#  {'from': '2026-04-02T16:30Z',
#   'intensity': {'actual': 139, 'forecast': 132, 'index': 'moderate'},
#   'to': '2026-04-02T17:00Z'},
#  {'from': '2026-04-02T17:00Z',
#   'intensity': {'actual': 146, 'forecast': 143, 'index': 'moderate'},
#   'to': '2026-04-02T17:30Z'},
#  {'from': '2026-04-02T17:30Z',
#   'intensity': {'actual': 158, 'forecast': 149, 'index': 'moderate'},
#   'to': '2026-04-02T18:00Z'},
#  {'from': '2026-04-02T18:00Z',
# ...
